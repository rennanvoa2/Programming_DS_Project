# %%
# Load the Pandas libraries with alias 'pd' 

import pandas as pd

# %%
# Read data from file 'International Arrivals.csv' that contains for each country or zone the number of international arrivals per year

arrivals=pd.read_csv('International Arrivals.csv', header=2)

#Select only the columns needed. Exclude information from 1960 to 1994 and 2018 that is empty

arrivals=arrivals[['Country Name', 'Country Code', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017']]

# %%
#Check the arrivals data frame

arrivals
# Out:
#                                           Country Name Country Code  \
# 0                                                Aruba          ABW
# 1                                          Afghanistan          AFG
# 2                                               Angola          AGO
# 3                                              Albania          ALB
# 4                                              Andorra          AND
# 5                                           Arab World          ARB
# 6                                 United Arab Emirates          ARE
# 7                                            Argentina          ARG
# 8                                              Armenia          ARM
# 9                                       American Samoa          ASM
# 10                                 Antigua and Barbuda          ATG
# 11                                           Australia          AUS
# 12                                             Austria          AUT
# ...

# %%
# Read data from file 'Metadata_Country.csv' containing further information about countries

metadata_country=pd.read_csv('Metadata_Country.csv')

# %%
#Check the metadata_country data frame

metadata_country
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFG                  South Asia           Low income
# 2            AGO          Sub-Saharan Africa  Lower middle income
# 3            ALB       Europe & Central Asia  Upper middle income
# 4            AND       Europe & Central Asia          High income
# 5            ARB                         NaN                  NaN
# 6            ARE  Middle East & North Africa          High income
# 7            ARG   Latin America & Caribbean  Upper middle income
# 8            ARM       Europe & Central Asia  Upper middle income
# 9            ASM         East Asia & Pacific  Upper middle income
# 10           ATG   Latin America & Caribbean          High income
# 11           AUS         East Asia & Pacific          High income
# 12           AUT       Europe & Central Asia          High income
# ...

# %%
#Merge both data frames on 'Country Code' to have consolidate information an create a new data frame called df

df=arrivals.merge(metadata_country, on='Country Code', how='left')

arrivals
# Out:
#                                           Country Name Country Code  \
# 0                                                Aruba          ABW
# 1                                          Afghanistan          AFG
# 2                                               Angola          AGO
# 3                                              Albania          ALB
# 4                                              Andorra          AND
# 5                                           Arab World          ARB
# 6                                 United Arab Emirates          ARE
# 7                                            Argentina          ARG
# 8                                              Armenia          ARM
# 9                                       American Samoa          ASM
# 10                                 Antigua and Barbuda          ATG
# 11                                           Australia          AUS
# 12                                             Austria          AUT
# ...

# %%
#Check the first rows of the new data frame

df.head()
# Out:
#   Country Name Country Code      1995      1996      1997      1998  \
# 0        Aruba          ABW  619000.0  641000.0  650000.0  647000.0
# 1  Afghanistan          AFG       NaN       NaN       NaN       NaN
# 2       Angola          AGO    9000.0   21000.0   45000.0   52000.0
# 3      Albania          ALB  304000.0  287000.0  119000.0  184000.0
# 4      Andorra          AND       NaN       NaN       NaN       NaN
#
#         1999       2000       2001       2002     ...           2013  \
# 0   683000.0   721000.0   691000.0   643000.0     ...       979000.0
# 1        NaN        NaN        NaN        NaN     ...            NaN
# 2    45000.0    51000.0    67000.0    91000.0     ...       650000.0
# 3   371000.0   317000.0   354000.0   470000.0     ...      2857000.0
# 4  2347000.0  2949000.0  3516000.0  3387000.0     ...      2328000.0
#
#         2014       2015       2016       2017                     Region  \
# ...

# %%
#Check our countries

df[df['TableName']=='Colombia']
# Out:
#    Country Name Country Code       1995      1996      1997      1998  \
# 43     Colombia          COL  1399000.0  631000.0  639000.0  674000.0
#
#         1999      2000      2001      2002     ...           2013       2014  \
# 43  546000.0  557000.0  616000.0  567000.0     ...      2288000.0  2552000.0
#
#          2015       2016       2017                     Region  \
# 43  2978000.0  3317000.0  4113000.0  Latin America & Caribbean
#
#             IncomeGroup  SpecialNotes  TableName  Unnamed: 5
# 43  Upper middle income           NaN   Colombia         NaN
#
# [1 rows x 30 columns]

# %%
df[df['TableName']=='Brazil']
# Out:
#    Country Name Country Code       1995       1996       1997       1998  \
# 27       Brazil          BRA  1991000.0  2666000.0  2850000.0  4818000.0
#
#          1999       2000       2001       2002     ...           2013  \
# 27  5107000.0  5313000.0  4773000.0  3785000.0     ...      5813000.0
#
#          2014       2015       2016       2017                     Region  \
# 27  6430000.0  6306000.0  6547000.0  6589000.0  Latin America & Caribbean
#
#             IncomeGroup  SpecialNotes  TableName  Unnamed: 5
# 27  Upper middle income           NaN     Brazil         NaN
#
# [1 rows x 30 columns]

# %%
df[df['TableName']=='Cambodia']
# Out:
#     Country Name Country Code      1995      1996      1997      1998  \
# 121     Cambodia          KHM  220000.0  260000.0  219000.0  287000.0
#
#          1999      2000      2001      2002     ...           2013       2014  \
# 121  368000.0  466000.0  605000.0  787000.0     ...      4210000.0  4503000.0
#
#           2015       2016       2017               Region  \
# 121  4775000.0  5012000.0  5602000.0  East Asia & Pacific
#
#              IncomeGroup  SpecialNotes  TableName  Unnamed: 5
# 121  Lower middle income           NaN   Cambodia         NaN
#
# [1 rows x 30 columns]

# %%
df[df['TableName']=='Portugal']
# Out:
#     Country Name Country Code       1995       1996       1997       1998  \
# 192     Portugal          PRT  4572000.0  4567000.0  4798000.0  5539000.0
#
#           1999       2000       2001       2002     ...           2013  \
# 192  5379000.0  5599000.0  5392000.0  5560000.0     ...      9177000.0
#
#            2014        2015        2016        2017                 Region  \
# 192  10497000.0  11723000.0  13359000.0  15432000.0  Europe & Central Asia
#
#      IncomeGroup                                       SpecialNotes  \
# 192  High income  A simple multiplier is used to convert the nat...
#
#      TableName  Unnamed: 5
# 192   Portugal         NaN
#
# [1 rows x 30 columns]

# %%
#Find the top 10 countries or regions with the most number of visitor in 2017

df.nlargest(10, ['2017'])
# Out:
#                   Country Name Country Code          1995          1996  \
# 257                      World          WLD  5.239096e+08  5.545516e+08
# 93                 High income          HIC  3.788522e+08  3.936993e+08
# 179               OECD members          OED  3.585940e+08  3.731950e+08
# 196  Post-demographic dividend          PST  3.291888e+08  3.429809e+08
# 63       Europe & Central Asia          ECS  2.955132e+08  3.116283e+08
# 101           IDA & IBRD total          IBT  1.661324e+08  1.830733e+08
# 71              European Union          EUU  2.587999e+08  2.677640e+08
# 138        Low & middle income          LMY  1.419560e+08  1.574997e+08
# 154              Middle income          MIC  1.364637e+08  1.513786e+08
# 100                  IBRD only          IBD  1.533753e+08  1.685863e+08
#
#              1997          1998          1999          2000          2001  \
# 257  5.843048e+08  6.022473e+08  6.272079e+08  6.773870e+08  6.782462e+08
# ...

# %%
#Find the top 10 countries exclusively with the most number of visitor in 2017. 
#We need to exclude Regions and Income Groups to look only for countries data

df[(df['Region'].notnull()) & (df['IncomeGroup'].notnull())].nlargest(10,['2017'])
# Out:
#        Country Name Country Code        1995        1996        1997  \
# 75           France          FRA  60033000.0  62406000.0  66591000.0
# 68            Spain          ESP  32971000.0  34027000.0  39553000.0
# 249   United States          USA  43318000.0  46489000.0  47767000.0
# 38            China          CHN  20034000.0  22765000.0  23770000.0
# 114           Italy          ITA  31052000.0  32943000.0  34692000.0
# 152          Mexico          MEX  20241000.0  21395000.0  19351000.0
# 79   United Kingdom          GBR  21719000.0  22936000.0  23215000.0
# 242          Turkey          TUR   7083000.0   7966000.0   9040000.0
# 53          Germany          DEU  14847000.0  15205000.0  15837000.0
# 231        Thailand          THA   6952000.0   7244000.0   7294000.0
#
#            1998        1999        2000        2001        2002     ...      \
# 75   70109000.0  73147000.0  77190000.0  75202000.0  77012000.0     ...
# ...

# %%
#Find the bottom 10 only countries exclusively with the most number of visitor in 2017. 

df[(df['Region'].notnull()) & (df['IncomeGroup'].notnull())].nsmallest(10,['2017'])
# Out:
#          Country Name Country Code     1995     1996     1997     1998  \
# 243            Tuvalu          TUV    900.0   1000.0   1000.0   1000.0
# 122          Kiribati          KIR   3900.0   4200.0   5100.0   5700.0
# 153  Marshall Islands          MHL   5500.0   6200.0   6400.0   6400.0
# 9      American Samoa          ASM  34000.0  35000.0  26000.0  36000.0
# 207   Solomon Islands          SLB  11800.0  10300.0  13800.0  15800.0
# 44            Comoros          COM  23000.0  24000.0  26000.0  27000.0
# 237             Tonga          TON  29000.0  27000.0  26000.0  27000.0
# 135     Liechtenstein          LIE  59000.0  56000.0  57000.0  59000.0
# 55           Dominica          DMA  60000.0  63000.0  65000.0  66000.0
# 235       Timor-Leste          TLS      NaN      NaN      NaN      NaN
#
#         1999     2000     2001     2002     ...         2013     2014  \
# 243   1100.0   1100.0   1100.0   1300.0     ...       1300.0   1400.0
# ...

# %%
df['Growth5ys']=(df['2017']/df['2012']-1)
df['Growth10ys']=(df['2017']/df['2007']-1)

# %%
df[df['Region'].notnull()].nlargest(10,['Growth5ys'])
# Out:
#       Country Name Country Code       1995       1996       1997       1998  \
# 39   Cote d'Ivoire          CIV        NaN        NaN        NaN        NaN
# 117          Japan          JPN  3345000.0  3837000.0  4218000.0  4106000.0
# 112        Iceland          ISL   190000.0   201000.0   202000.0   232000.0
# 158        Myanmar          MMR   194000.0   490000.0   491000.0   478000.0
# 193       Paraguay          PRY   438000.0   426000.0   395000.0   350000.0
# 139        Lesotho          LSO   209000.0   312000.0   313000.0   290000.0
# 30          Bhutan          BTN     4800.0     5200.0     5400.0     6200.0
# 107          India          IND  2124000.0  2288000.0  2374000.0  2359000.0
# 243         Tuvalu          TUV      900.0     1000.0     1000.0     1000.0
# 230           Togo          TGO    53000.0    58000.0    92000.0    69000.0
#
#           1999       2000       2001       2002     ...            2015  \
# ...

# %%
df.loc[df['Region'].notnull(),['Country Name','Growth5ys','Growth10ys']].nlargest(10,'Growth5ys')
# Out:
#       Country Name  Growth5ys  Growth10ys
# 39   Cote d'Ivoire   5.228374    8.890110
# 117          Japan   2.432759    2.437283
# 112        Iceland   2.306092    3.587629
# 158        Myanmar   2.251180    3.808659
# 193       Paraguay   1.735751    2.807692
# 139        Lesotho   1.687943    2.790000
# 30          Bhutan   1.428571   11.142857
# 107          India   1.362876    2.058442
# 243         Tuvalu   1.272727    1.272727
# 230           Togo   1.110638    4.767442

# %%
df1= df[['Country Name','Country Code']]

# %%
x=1996
while x<2018:
    df1.loc[:,str(x)]=((df.loc[:,str(x)]-df.loc[:,str(x-1)])/df.loc[:,str(x)])
    x+=1

# %%
df1
# Out:
#                                           Country Name Country Code      1996  \
# 0                                                Aruba          ABW  0.034321
# 1                                          Afghanistan          AFG       NaN
# 2                                               Angola          AGO  0.571429
# 3                                              Albania          ALB -0.059233
# 4                                              Andorra          AND       NaN
# 5                                           Arab World          ARB  0.035288
# 6                                 United Arab Emirates          ARE  0.099922
# 7                                            Argentina          ARG  0.124331
# 8                                              Armenia          ARM  0.076923
# 9                                       American Samoa          ASM  0.028571
# 10                                 Antigua and Barbuda          ATG  0.035088
# ...

# %%
df1.loc[df['Region'].notnull()]
df1.dropna(thresh=2)
# Out:
#                                           Country Name Country Code  \
# 0                                                Aruba          ABW
# 1                                          Afghanistan          AFG
# 2                                               Angola          AGO
# 3                                              Albania          ALB
# 4                                              Andorra          AND
# 5                                           Arab World          ARB
# 6                                 United Arab Emirates          ARE
# 7                                            Argentina          ARG
# 8                                              Armenia          ARM
# 9                                       American Samoa          ASM
# 10                                 Antigua and Barbuda          ATG
# 11                                           Australia          AUS
# 12                                             Austria          AUT
# ...

# %%
del df1
